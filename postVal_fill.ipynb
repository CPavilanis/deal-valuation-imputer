# %%
import pandas as pd
import numpy as np
import sklearn

# %%
companies = pd.read_parquet('companies.parquet', engine='fastparquet')
deals = pd.read_parquet('deals.parquet', engine='fastparquet')
print('Loaded companies and deals; join is handled by EDA (data_clean.ipynb)')
# Out:
# Loaded companies and deals; join is handled by EDA (data_clean.ipynb)

# %% [markdown]
# ## Transforming and cleaning "deals"

# %%
print('Joining companies onto deals (left join on CompanyID)')

_deals = deals.copy()
_companies = companies.copy()

deals_joined = _deals.merge(_companies, on='CompanyID', how='left')
matched = deals_joined['RowID_y'].notna().sum()

print(f'Before shape: {_deals.shape}, After shape: {deals_joined.shape}, Matched company rows: {matched}')

# write joined parquet for reuse by EDA and other scripts
joined_path = 'deals_joined.parquet'
deals_joined.to_parquet(joined_path, index=False)
print(f'Wrote joined parquet: {joined_path} (rows: {len(deals_joined)})')
# Out:
# Joining companies onto deals (left join on CompanyID)
# Before shape: (30680, 39), After shape: (30680, 79), Matched company rows: 30680
# Wrote joined parquet: deals_joined.parquet (rows: 30680)

# %%
deals_joined.columns
# Out:
# Index(['CompanyID', 'CompanyName_x', 'DealNo', 'DealDate', 'AnnouncedDate',
#        'DealSize', 'DealStatus', 'DealSizeStatus', 'PremoneyValuation',
#        'PostValuation', 'PostValuationStatus', 'PercentAcquired',
#        'RaisedToDate', 'VCRound', 'VCRoundUp_Down_Flat',
#        'TotalInvestedCapital', 'InvestorOwnership', 'StockSplit', 'DealType',
#        'DealType2', 'DealType3', 'DealClass', 'DealSynopsis',
#        'NativeCurrencyOfDeal', 'TotalInvestedEquity', 'AddOn', 'AddOnSponsors',
#        'AddOnPlatform', 'TotalNewDebt', 'Debts', 'DebtRaisedInRound',
#        'ContingentPayout', 'Employees_x', 'BusinessStatus_x',
#        'FinancingStatus', 'SiteLocation', 'ExitScope', 'RowID_x',
#        'LastUpdated_x', 'CompanyName_y', 'CompanyAlsoKnownAs',
#        'CompanyFormerName', 'CompanyLegalName', 'Description', 'Keywords',
#        'CompanyFinancingStatus', 'CompanyFinancingStatusDate', 'TotalRaised',
#        'TotalRaisedNativeAmount', 'TotalRaisedNativeCurrency',
#        'BusinessStatus_y', 'BusinessStatusDate', 'OwnershipStatus',
#        'OwnershipStatusDate', 'Universe', 'Website', 'Employees_y',
#        'EmployeeAsOfDate', 'DescriptionShort', 'Exchange', 'Ticker',
#        'YearFounded', 'ParentCompany', 'ParentCompanyID',
#        'FinancingStatusNote', 'FinancingStatusNoteAsOfDate',
#        'FacebookProfileURL', 'TwitterProfileURL', 'LinkedInProfileURL',
#        'PrimaryContactPBId', 'PrimaryContactFirstName',
#        'PrimaryContactLastName', 'PrimaryContactMiddle',
#        'PrimaryContactPrefix', 'PrimaryContactSuffix', 'PrimaryContact',
#        'PrimaryContactTitle', 'RowID_y', 'LastUpdated_y'],
#       dtype='object')

# %%
deals_joined

# %%
for dtcol in ['DealDate','AnnouncedDate']:
    deals_joined[dtcol + '_year'] = deals_joined[dtcol].dt.year

# %%
numerical_feat = ["DealNo", "DealSize", "PercentAcquired", "RaisedToDate", "TotalInvestedCapital", "TotalInvestedEquity", "TotalNewDebt", "DebtRaisedInRound", "TotalRaised", "TotalRaisedNativeAmount", "Employees_y", "YearFounded", "DealDate_year", "AnnouncedDate_year"]
# categorical_feat = ["NativeCurrencyOfDeal", "AddOn", "BusinessStatus_x", "FinancingStatus", "CompanyFinancingStatus", "BusinessStatus_y"]

# run imputer

deals_joined_log = deals_joined.copy()

for col in numerical_feat:
    # Set log to NaN where value <= 0
    deals_joined_log[col] = np.where(deals_joined_log[col] > 0, np.log(deals_joined_log[col]), np.nan)


df_imputed, model = imputer.impute_df_basic(
    deals_joined, 
    feature_cols=numerical_feat,
    target_col='PostValuation')

# df_imputed, model = imputer.impute_df_basic(
#     deals_joined, 
#     feature_cols=[
#     "DealNo", "DealSize", "PremoneyValuation", 
#     "PercentAcquired", "RaisedToDate", 
#     "TotalInvestedCapital", "InvestorOwnership", 
#     "TotalInvestedEquity", "TotalNewDebt", "DebtRaisedInRound", 
#     "ContingentPayout", "Employees_x", "TotalRaised", 
#     "TotalRaisedNativeAmount", "Employees_y", "YearFounded", 
#     "DealDate_year", "AnnouncedDate_year",'DealType'],
#     categorical_cols=['DealType'],
#     target_col='PostValuation')

df_imputed, model = imputer.impute_df_basic(
    deals_joined, 
    feature_cols=numerical_feat+categorical_feat,
    categorical_cols = categorical_feat,
    target_col='PostValuation')

# Train RMSE: 586.0705, Train R2: 0.9526
# Test  RMSE: 1016.5981, Test R2: 0.8911
# Train RMSE: 570.3943, Train R2: 0.9551
# Test  RMSE: 1134.0478, Test R2: 0.8645
# Out:
# /Users/c0p0frj/Library/Python/3.9/lib/python/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Train RMSE: 586.0705, Train R2: 0.9526
# Test  RMSE: 1016.5981, Test R2: 0.8911
# Train RMSE: 577.6674, Train R2: 0.9539
# Test  RMSE: 1092.2788, Test R2: 0.8743

# %%
# Run minimal imputer from scripts/impute_postvaluation.py using only Employees as feature
from importlib import util
spec = util.spec_from_file_location('imputer_mod', 'scripts/impute_postvaluation.py')
imputer = util.module_from_spec(spec)
spec.loader.exec_module(imputer)

dfimputed, model = imputer.impute_df_basic(
    deals_joined,
    numerical = [
        'DealSize', 'PremoneyValuation', 'PercentAcquired', 'RaisedToDate', 'TotalInvestedCapital', 
        'InvestorOwnership', 'TotalInvestedEquity', 'TotalNewDebt', 'DebtRaisedInRound', 
        'ContingentPayout', 'Employees_x', 'TotalRaised', 
        'TotalRaisedNativeAmount', 'Employees_y', 'YearFounded', 'DealDate_year', 'AnnouncedDate_year'],
    numerical_to_log=[],
    categorical=[
        'DealStatus','DealSizeStatus','PostValuationStatus','VCRound','VCRoundUp_Down_Flat',
        'DealType','DealType2','DealType3','DealClass','NativeCurrencyOfDeal','AddOn',
        'BusinessStatus_x','FinancingStatus','SiteLocation','ExitScope','CompanyFinancingStatus',
        'TotalRaisedNativeCurrency','OwnershipStatus','Universe','Exchange','PrimaryContactPrefix',
        'PrimaryContactSuffix','PrimaryContactTitle'],
    target_col='PostValuation'
)

# Train RMSE: 474.1165, Train R2: 0.9690
# Test  RMSE: 1249.9156, Test R2: 0.8353


# Train RMSE: 511.4826, Train R2: 0.9639
# Test  RMSE: 1531.9159, Test R2: 0.7527

# {'bootstrap': True, 'ccp_alpha': 0.0, 'criterion': 'squared_error', 'max_depth': 15, 'max_features': 1.0, 'max_leaf_nodes': None, 'max_samples': None, 'min_impurity_decrease': 0.0, 'min_samples_leaf': 2, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'monotonic_cst': None, 'n_estimators': 100, 'n_jobs': -1, 'oob_score': False, 'random_state': 1, 'verbose': 0, 'warm_start': False}
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  16.9s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  17.3s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  18.2s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  17.4s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  23.9s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  24.0s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  24.6s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  25.6s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  24.6s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  24.3s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  21.7s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  23.5s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  25.0s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  24.9s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time=  44.3s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time=  44.7s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time=  45.0s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time=  45.3s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time=  45.2s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time=  44.4s
# /Users/c0p0frj/Library/Python/3.9/lib/python/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time=  38.1s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time=  37.2s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time=  29.5s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time=  29.4s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time=  28.4s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time=  28.4s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time=  29.1s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time=  29.2s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time=  28.8s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time=  28.9s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time=  28.9s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time=  29.1s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time=  25.0s
# [CV] END bootstrap=True, max_depth=5, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time=  24.5s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  17.3s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  19.1s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  19.8s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  18.4s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  20.5s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  24.0s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  24.5s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  23.0s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  19.8s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  18.8s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  18.4s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  18.2s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  18.2s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  15.1s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  11.3s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  11.9s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  12.0s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  12.1s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  12.2s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  11.7s
# [CV] END bootstrap=True, max_depth=10, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  11.6s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time=  24.5s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time=  23.7s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time=  24.9s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time=  23.8s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time=  24.4s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time=  28.7s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  12.4s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time=  37.3s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time=  39.2s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time=  38.9s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time=  34.9s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time=  37.3s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time=  36.9s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  19.2s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time=  43.3s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time=  49.0s
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time=  49.1s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  29.7s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  31.7s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  20.4s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  37.6s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  38.5s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=1, min_samples_split=2; total time=  38.2s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  36.3s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  35.8s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  44.1s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  43.6s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  33.4s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=1, min_samples_split=3; total time=  45.6s
# [CV] END bootstrap=True, max_depth=5, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  31.6s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  44.3s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  44.5s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  50.8s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  50.1s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=2, min_samples_split=2; total time=  51.2s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  50.6s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  49.1s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  48.9s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  47.1s
# [CV] END bootstrap=True, max_depth=15, max_features=0.5, min_samples_leaf=2, min_samples_split=3; total time=  49.3s
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time= 1.7min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time= 1.8min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time= 1.8min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time= 1.8min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=1, min_samples_split=2; total time= 1.7min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time= 1.7min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time= 1.6min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time= 1.8min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time= 1.7min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time= 1.7min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time= 1.7min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time= 1.6min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time= 1.7min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time= 1.6min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time= 1.5min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time= 1.5min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time= 1.5min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time= 1.5min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time= 1.5min
# [CV] END bootstrap=True, max_depth=15, max_features=1.0, min_samples_leaf=2, min_samples_split=3; total time= 1.3min
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time= 1.1min
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time= 1.1min
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=1, min_samples_split=3; total time= 1.1min
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time= 1.1min
# [CV] END bootstrap=True, max_depth=10, max_features=1.0, min_samples_leaf=2, min_samples_split=2; total time= 1.1min
# Train RMSE: 752.6758, Train R2: 0.9217
# Test  RMSE: 1282.7044, Test R2: 0.8266

# %%
# Run minimal imputer from scripts/impute_postvaluation.py using only Employees as feature
from importlib import util
spec = util.spec_from_file_location('imputer_mod', 'scripts/impute_postvaluation.py')
imputer = util.module_from_spec(spec)
spec.loader.exec_module(imputer)

dfimputed, model = imputer.impute_df_basic(
    deals_joined,
    numerical = [
        'PercentAcquired',
        'InvestorOwnership', 'TotalNewDebt',
        'ContingentPayout', 'Employees_x', 
        'Employees_y', 'YearFounded', 'DealDate_year', 'AnnouncedDate_year'
        ],
    numerical_to_log=[
        'DealSize', 'PremoneyValuation', 'RaisedToDate', 'TotalInvestedCapital', 
        'DebtRaisedInRound', 'TotalInvestedEquity','TotalRaised','TotalRaisedNativeAmount'
    ],
    categorical=[
        'DealStatus','DealSizeStatus','PostValuationStatus','VCRound','VCRoundUp_Down_Flat',
        'DealType','DealType2','DealType3','DealClass','NativeCurrencyOfDeal','AddOn',
        'BusinessStatus_x','FinancingStatus','SiteLocation','ExitScope','CompanyFinancingStatus',
        'TotalRaisedNativeCurrency','OwnershipStatus','Universe','Exchange','PrimaryContactPrefix',
        'PrimaryContactSuffix','PrimaryContactTitle'],
    target_col='PostValuation'
)

# Train RMSE: 598.9358, Train R2: 0.9569
# Test  RMSE: 764.9720, Test R2: 0.8869


# xgboost
# Train RMSE: 28.1177, Train R2: 0.9999
# Test  RMSE: 1500.6531, Test R2: 0.5648
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 7
#       4 imputer = util.module_from_spec(spec)
#       5 spec.loader.exec_module(imputer)
# ----> 7 dfimputed, model = imputer.impute_df_basic(
#       8     deals_joined,
#       9     numerical = [
#      10         'PercentAcquired',
#      11         'InvestorOwnership', 'TotalInvestedEquity', 'TotalNewDebt', '',
#      12         'ContingentPayout', 'Employees_x', 'TotalRaised',
#      13         'TotalRaisedNativeAmount', 'Employees_y', 'YearFounded', 'DealDate_year', 'AnnouncedDate_year'
#      14         ],
#      15     numerical_to_log=[
#      16         'DealSize', 'PremoneyValuation', 'RaisedToDate', 'TotalInvestedCapital', 'DebtRaisedInRound'
#      17     ],
#      18     categorical=[
#      19         'DealStatus','DealSizeStatus','PostValuationStatus','VCRound','VCRoundUp_Down_Flat',
#      20         'DealType','DealType2','DealType3','DealClass','NativeCurrencyOfDeal','AddOn',
#      21         'BusinessStatus_x','FinancingStatus','SiteLocation','ExitScope','CompanyFinancingStatus',
#      22         'TotalRaisedNativeCurrency','OwnershipStatus','Universe','Exchange','PrimaryContactPrefix',
#      23         'PrimaryContactSuffix','PrimaryContactTitle'],
#      24     target_col='PostValuation'
#      25 )
#      27 # Train RMSE: 598.9358, Train R2: 0.9569
#      28 # Test  RMSE: 764.9720, Test R2: 0.8869
#      29
#    (...)
#      32 # Train RMSE: 28.1177, Train R2: 0.9999
#      33 # Test  RMSE: 1500.6531, Test R2: 0.5648
#
# File ~/Documents/deal-valuation-imputer/scripts/impute_postvaluation.py:59, in impute_df_basic(df, numerical, numerical_to_log, categorical, target_col)
#      55 feature_cols = numerical + logcols + categorical_expanded
#      57 mask_known = df[target_col].notna()
# ---> 59 X_known = df.loc[mask_known, feature_cols].values
#      60 y_known = df.loc[mask_known, target_col].values
#      62 # split known data to estimate train/test error
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:1185, in _LocationIndexer.__getitem__(self, key)
#    1183     if self._is_scalar_access(key):
#    1184         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1185     return self._getitem_tuple(key)
#    1186 else:
#    1187     # we by definition only have the 0th axis
#    1188     axis = self.axis or 0
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:1378, in _LocIndexer._getitem_tuple(self, tup)
#    1375 if self._multi_take_opportunity(tup):
#    1376     return self._multi_take(tup)
# -> 1378 return self._getitem_tuple_same_dim(tup)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:1021, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#    1018 if com.is_null_slice(key):
#    1019     continue
# -> 1021 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#    1022 # We should never have retval.ndim < self.ndim, as that should
#    1023 #  be handled by the _getitem_lowerdim call above.
#    1024 assert retval.ndim == self.ndim
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:1421, in _LocIndexer._getitem_axis(self, key, axis)
#    1418     if hasattr(key, "ndim") and key.ndim > 1:
#    1419         raise ValueError("Cannot index with multidimensional key")
# -> 1421     return self._getitem_iterable(key, axis=axis)
#    1423 # nested tuple slicing
#    1424 if is_nested_tuple(key, labels):
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:1361, in _LocIndexer._getitem_iterable(self, key, axis)
#    1358 self._validate_key(key, axis)
#    1360 # A collection of keys
# -> 1361 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1362 return self.obj._reindex_with_indexers(
#    1363     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1364 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexing.py:1559, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1556 ax = self.obj._get_axis(axis)
#    1557 axis_name = self.obj._get_axis_name(axis)
# -> 1559 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1561 return keyarr, indexer
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/indexes/base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "[''] not in index"

# %%
import sys
print(sys.executable)
# Out:
# /Library/Developer/CommandLineTools/usr/bin/python3

# %%
deals_joined[['DealNo']]

for col in deals_joined.columns:
    print(f"--- Column: {col} ---")
    # Get value counts for the current column, sorted in descending order
    value_counts = deals_joined[col].value_counts()

    # Get the top 5 distinct values and their counts
    top_5 = value_counts.head(5)
    print(top_5)
